# %% [markdown]
# ## Import

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %%
pwd
# Out:
# '/Users/marijansoric/Documents/GitHub/Solar-Energy-Production-Forecasting/marijan'

# %%
pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-13.0.0-cp39-cp39-macosx_10_14_x86_64.whl (25.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.9/25.9 MB 6.0 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: numpy>=1.16.6 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from pyarrow) (1.23.5)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-13.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastparquet
# Out:
# Collecting fastparquet
#   Downloading fastparquet-2023.8.0-cp39-cp39-macosx_10_9_universal2.whl (911 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.3/911.3 kB 8.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: fsspec in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from fastparquet) (2022.11.0)
# Requirement already satisfied: packaging in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from fastparquet) (23.1)
# Collecting cramjam>=2.3
#   Downloading cramjam-2.7.0-cp39-cp39-macosx_10_9_x86_64.macosx_11_0_arm64.macosx_10_9_universal2.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 11.4 MB/s eta 0:00:0000:0100:01
# Collecting pandas>=1.5.0
#   Downloading pandas-2.1.1-cp39-cp39-macosx_10_9_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 10.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.20.3 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from fastparquet) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.5.0->fastparquet) (2022.7)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: six>=1.5 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.16.0)
# Installing collected packages: tzdata, cramjam, pandas, fastparquet
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.4
#     Uninstalling pandas-1.4.4:
#       Successfully uninstalled pandas-1.4.4
# Successfully installed cramjam-2.7.0 fastparquet-2023.8.0 pandas-2.1.1 tzdata-2023.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.5.1-py2.py3-none-any.whl (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.3/357.3 kB 5.1 MB/s eta 0:00:0000:01
# Requirement already satisfied: matplotlib<4,>=3.2 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling) (3.6.2)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 2.4 MB/s eta 0:00:0000:01
# Collecting wordcloud>=1.9.1
#   Downloading wordcloud-1.9.2-cp39-cp39-macosx_10_9_x86_64.whl (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.1/161.1 kB 3.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling) (1.23.5)
# Collecting imagehash==4.3.1
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 5.2 MB/s eta 0:00:00a 0:00:01
# Collecting typeguard<3,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.3-cp39-cp39-macosx_10_13_x86_64.whl (652 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.0/653.0 kB 3.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling) (6.0)
# Collecting pydantic<2,>=1.8.1
#   Downloading pydantic-1.10.12-cp39-cp39-macosx_10_9_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 8.3 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling) (2.11.3)
# Requirement already satisfied: scipy<1.12,>=1.4.1 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling) (1.10.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling) (0.12.2)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling) (4.64.1)
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3,>=2.24.0 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling) (2.28.1)
# Collecting pandas!=1.4.0,<2.1,>1.1
#   Downloading pandas-2.0.3-cp39-cp39-macosx_10_9_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 7.8 MB/s eta 0:00:00:00:0100:01
# Collecting dacite>=1.8
#   Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Collecting multimethod<2,>=1.4
#   Downloading multimethod-1.10-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling) (0.13.5)
# Requirement already satisfied: PyWavelets in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling) (1.4.1)
# Requirement already satisfied: pillow in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling) (9.3.0)
# Requirement already satisfied: attrs>=19.3.0 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (22.1.0)
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 9.1 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: networkx>=2.4 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (2.8.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (23.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from pydantic<2,>=1.8.1->ydata-profiling) (4.7.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2023.7.22)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4)
# Requirement already satisfied: patsy>=0.5.2 in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.3)
# Requirement already satisfied: six in /Users/marijansoric/opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27082 sha256=9d4a655207766149158126bf106d2ee26102fd6290ad49333357bed0f39ba2ef
#   Stored in directory: /Users/marijansoric/Library/Caches/pip/wheels/ab/a0/78/885e94cd7af32ff120febdad1870c5381c884d7f4b332d58dd
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, tangled-up-in-unicode, pydantic, multimethod, dacite, pandas, imagehash, wordcloud, visions, phik, ydata-profiling
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.1
#     Uninstalling pandas-2.1.1:
#       Successfully uninstalled pandas-2.1.1
# Successfully installed dacite-1.8.1 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.10 pandas-2.0.3 phik-0.12.3 pydantic-1.10.12 tangled-up-in-unicode-0.2.0 typeguard-2.13.3 visions-0.7.5 wordcloud-1.9.2 ydata-profiling-4.5.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Data

# %%
y = pd.read_csv('y_a.csv', index_col='time', parse_dates=True)
X_est = pd.read_csv('X_est.csv', index_col='date_forecast', parse_dates=True)
X_obs = pd.read_csv('X_obs.csv', index_col='date_forecast', parse_dates=True)

y.drop(['Unnamed: 0'], axis=1, inplace=True)
X_est.drop(['Unnamed: 0'], axis=1, inplace=True)
X_obs.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
X_test = pd.read_csv('X_test.csv', index_col='date_forecast', parse_dates=True)

X_test.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# Train
train_a = pd.read_parquet('A/train_targets.parquet')
train_b = pd.read_parquet('B/train_targets.parquet')
train_c = pd.read_parquet('C/train_targets.parquet')

# %%
# X_train_estimated
X_train_estimated_a = pd.read_parquet('A/X_train_estimated.parquet')
X_train_estimated_b = pd.read_parquet('B/X_train_estimated.parquet')
X_train_estimated_c = pd.read_parquet('C/X_train_estimated.parquet')

# %%
# X_train_observed
X_train_observed_a = pd.read_parquet('A/X_train_observed.parquet')
X_train_observed_b = pd.read_parquet('B/X_train_observed.parquet')
X_train_observed_c = pd.read_parquet('C/X_train_observed.parquet')

# %%
X_test_estimated_a = pd.read_parquet('A/X_test_estimated.parquet')
X_test_estimated_b = pd.read_parquet('B/X_test_estimated.parquet')
X_test_estimated_c = pd.read_parquet('C/X_test_estimated.parquet')

# %%
X_test_estimated_a.to_csv('X_test.csv')

# %%
pip install ydata-profiling

from ydata_profiling import ProfileReport

profile = ProfileReport(X_train_estimated_a, title="Profiling Report")
profile.to_file("Marijan.html")

# %%
train_a.to_csv('y_a.csv')

# %% [markdown]
# ## Some plots

# %%
X = pd.merge(X_obs, y, left_index=True, right_index=True)

# %%
X_obs['absolute_humidity_2m:gm3'].loc[:].hist()
# Out:
# <AxesSubplot: >

# %%
X_est['absolute_humidity_2m:gm3'].hist()
# Out:
# <AxesSubplot: >

# %%
print(X_obs['absolute_humidity_2m:gm3'].describe(),
X_est['absolute_humidity_2m:gm3'].describe())
# Out:
# count    118669.000000
# mean          6.652576
# std           2.796348
# min           0.700000
# 25%           4.400000
# 50%           6.300000
# 75%           8.600000
# max          17.500000
# Name: absolute_humidity_2m:gm3, dtype: float64 count    17576.000000
# mean         4.092439
# std          1.511150
# min          1.000000
# 25%          3.000000
# 50%          3.900000
# 75%          5.100000
# max          8.800000
# Name: absolute_humidity_2m:gm3, dtype: float64

# %% [markdown]
# Idea : apply a linear transformation to obtain a X_obs based on X_est, for the same seasonality.

# %%
X_obs['absolute_humidity_2m:gm3'].resample('M').mean().plot(marker='+'), 
X_est['absolute_humidity_2m:gm3'].resample('M').mean().plot(marker='+'), 
X_test['absolute_humidity_2m:gm3'].resample('M').mean().plot(marker='+'),
# Out:
# (<AxesSubplot: xlabel='date_forecast'>,)

# %%
X_obs['absolute_humidity_2m:gm3'].loc['2022-06':].resample('D').mean().plot(),
X_est['absolute_humidity_2m:gm3'].resample('D').mean().plot(),
X_test['absolute_humidity_2m:gm3'].resample('D').mean().plot(marker='x'),
# Out:
# (<AxesSubplot: xlabel='date_forecast'>,)

# %%
y.index
# Out:
# DatetimeIndex(['2019-06-02 22:00:00', '2019-06-02 23:00:00',
#                '2019-06-03 00:00:00', '2019-06-03 01:00:00',
#                '2019-06-03 02:00:00', '2019-06-03 03:00:00',
#                '2019-06-03 04:00:00', '2019-06-03 05:00:00',
#                '2019-06-03 06:00:00', '2019-06-03 07:00:00',
#                ...
#                '2023-04-30 14:00:00', '2023-04-30 15:00:00',
#                '2023-04-30 16:00:00', '2023-04-30 17:00:00',
#                '2023-04-30 18:00:00', '2023-04-30 19:00:00',
#                '2023-04-30 20:00:00', '2023-04-30 21:00:00',
#                '2023-04-30 22:00:00', '2023-04-30 23:00:00'],
#               dtype='datetime64[ns]', name='time', length=34085, freq=None)

# %%
X_test.index
# Out:
# DatetimeIndex(['2023-05-01 00:00:00', '2023-05-01 00:15:00',
#                '2023-05-01 00:30:00', '2023-05-01 00:45:00',
#                '2023-05-01 01:00:00', '2023-05-01 01:15:00',
#                '2023-05-01 01:30:00', '2023-05-01 01:45:00',
#                '2023-05-01 02:00:00', '2023-05-01 02:15:00',
#                ...
#                '2023-07-03 21:30:00', '2023-07-03 21:45:00',
#                '2023-07-03 22:00:00', '2023-07-03 22:15:00',
#                '2023-07-03 22:30:00', '2023-07-03 22:45:00',
#                '2023-07-03 23:00:00', '2023-07-03 23:15:00',
#                '2023-07-03 23:30:00', '2023-07-03 23:45:00'],
#               dtype='datetime64[ns]', name='date_forecast', length=2880, freq=None)

# %%
X_obs.describe()
# Out:
#        absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# count             118669.000000        118669.000000          96422.000000
# mean                   6.652576             1.249064           2907.949201
# std                    2.796348             0.036319           2570.413231
# min                    0.700000             1.145000             27.800000
# 25%                    4.400000             1.224000           1102.900000
# 50%                    6.300000             1.247000           1882.400000
# 75%                    8.600000             1.272000           3969.750000
# max                   17.500000             1.427000          12328.500000
#
#        clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  \
# count           1.186690e+05    118669.000000     110603.000000
# mean            5.994017e+05       166.500415       1737.142229
# std             8.795423e+05       244.945361       1815.584087
# min             0.000000e+00         0.000000         27.900000
# 25%             0.000000e+00         0.000000        590.700000
# 50%             3.574770e+04         8.600000       1162.600000
# 75%             1.037819e+06       288.800000       2079.600000
# max             3.005720e+06       836.400000      11688.700000
#
#        dew_or_rime:idx  dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  \
# count    118669.000000   118669.000000  118669.000000      1.186690e+05
# mean          0.022398      276.823354      44.918279      1.617057e+05
# std           0.190367        6.701763      64.786696      2.301970e+05
# min          -1.000000      250.900000       0.000000      0.000000e+00
# 25%           0.000000      272.100000       0.000000      0.000000e+00
# 50%           0.000000      277.200000       4.100000      2.481410e+04
# 75%           0.000000      282.000000      76.000000      2.743256e+05
# max           1.000000      293.800000     345.700000      1.205498e+06
#
#         direct_rad:W  direct_rad_1h:J  effective_cloud_cover:p  elevation:m  \
# count  118669.000000     1.186690e+05            118669.000000     118669.0
# mean       56.611736     2.038025e+05                67.605501          6.0
# std       119.755807     4.247662e+05                33.859708          0.0
# min         0.000000     0.000000e+00                 0.000000          6.0
# 25%         0.000000     0.000000e+00                43.300000          6.0
# 50%         0.000000     8.960000e+01                80.500000          6.0
# 75%        41.800000     1.598314e+05                98.800000          6.0
# max       688.700000     2.451173e+06               100.000000          6.0
#
#        fresh_snow_12h:cm  fresh_snow_1h:cm  fresh_snow_24h:cm  \
# count      118669.000000     118669.000000      118669.000000
# mean            0.053117          0.004418           0.106243
# std             0.490255          0.075688           0.746683
# min             0.000000          0.000000           0.000000
# 25%             0.000000          0.000000           0.000000
# 50%             0.000000          0.000000           0.000000
# 75%             0.000000          0.000000           0.000000
# max            15.100000          3.900000          15.100000
#
#        fresh_snow_3h:cm  fresh_snow_6h:cm     is_day:idx  is_in_shadow:idx  \
# count     118669.000000     118669.000000  118669.000000     118669.000000
# mean           0.013277          0.026567       0.521391          0.511650
# std            0.181613          0.306374       0.499544          0.499866
# min            0.000000          0.000000       0.000000          0.000000
# 25%            0.000000          0.000000       0.000000          0.000000
# 50%            0.000000          0.000000       1.000000          1.000000
# 75%            0.000000          0.000000       1.000000          1.000000
# max            7.900000         14.800000       1.000000          1.000000
#
#        msl_pressure:hPa  precip_5min:mm  precip_type_5min:idx  \
# count     118669.000000   118669.000000         118669.000000
# mean        1009.632894        0.006302              0.091018
# std           12.484964        0.037386              0.379626
# min          944.300000        0.000000              0.000000
# 25%         1002.100000        0.000000              0.000000
# 50%         1010.700000        0.000000              0.000000
# 75%         1018.300000        0.000000              0.000000
# max         1044.000000        2.230000              6.000000
#
#        pressure_100m:hPa  pressure_50m:hPa    prob_rime:p  rain_water:kgm2  \
# count      118669.000000     118669.000000  118669.000000    118669.000000
# mean          996.765394       1002.868266       0.187399         0.011914
# std            12.350945         12.404964       2.517710         0.047563
# min           932.300000        938.100000       0.000000         0.000000
# 25%           989.300000        995.300000       0.000000         0.000000
# 50%           997.900000       1003.900000       0.000000         0.000000
# 75%          1005.400000       1011.500000       0.000000         0.000000
# max          1030.900000       1037.300000      83.400000         1.400000
#
#        relative_humidity_1000hPa:p  sfc_pressure:hPa  snow_density:kgm3  \
# count                118669.000000     118669.000000             2724.0
# mean                     74.231693       1008.998260              250.0
# std                      13.889466         12.461081                0.0
# min                      22.700000        943.900000              250.0
# 25%                      65.000000       1001.400000              250.0
# 50%                      76.700000       1010.000000              250.0
# 75%                      85.400000       1017.600000              250.0
# max                     100.000000       1043.800000              250.0
#
#        snow_depth:cm  snow_drift:idx  snow_melt_10min:mm  snow_water:kgm2  \
# count  118669.000000        118669.0       118669.000000    118669.000000
# mean        0.052763             0.0            0.000062         0.091566
# std         0.409511             0.0            0.001885         0.249349
# min         0.000000             0.0           -0.000000         0.000000
# 25%         0.000000             0.0            0.000000         0.000000
# 50%         0.000000             0.0            0.000000         0.000000
# 75%         0.000000             0.0            0.000000         0.100000
# max         6.300000             0.0            0.120000         6.900000
#
#        sun_azimuth:d  sun_elevation:d  super_cooled_liquid_water:kgm2  \
# count  118669.000000    118669.000000                   118669.000000
# mean      179.629502         1.529544                        0.059087
# std       103.779365        24.146885                        0.109496
# min         0.002000       -50.004000                        0.000000
# 25%        88.488000       -15.066000                        0.000000
# 50%       179.437000         1.202000                        0.000000
# 75%       270.641000        18.995000                        0.100000
# max       359.998000        49.999000                        1.400000
#
#          t_1000hPa:K  total_cloud_cover:p   visibility:m  wind_speed_10m:ms  \
# count  118669.000000        118669.000000  118669.000000      118669.000000
# mean      280.708586            74.401077   32446.991933           3.043197
# std         6.573763            33.515800   17968.045184           1.779247
# min       258.900000             0.000000     154.300000           0.000000
# 25%       275.900000            54.800000   15592.400000           1.700000
# 50%       280.700000            93.700000   36359.800000           2.700000
# 75%       285.200000            99.900000   48084.500000           4.100000
# max       303.300000           100.000000   71349.900000          15.200000
#
#        wind_speed_u_10m:ms  wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms
# count        118669.000000        118669.000000            118669.000000
# mean              0.756781             0.517437                 0.000019
# std               2.856113             1.851790                 0.001392
# min              -7.300000            -9.300000                -0.000000
# 25%              -1.400000            -0.700000                 0.000000
# 50%               0.400000             0.500000                 0.000000
# 75%               2.700000             1.700000                 0.000000
# max              12.300000             8.600000                 0.100000

# %%
X_obs.iloc[:,3].hist()
# Out:
# <AxesSubplot: >

# %%
X.dtypes
# Out:
# absolute_humidity_2m:gm3          float64
# air_density_2m:kgm3               float64
# ceiling_height_agl:m              float64
# clear_sky_energy_1h:J             float64
# clear_sky_rad:W                   float64
# cloud_base_agl:m                  float64
# dew_or_rime:idx                   float64
# dew_point_2m:K                    float64
# diffuse_rad:W                     float64
# diffuse_rad_1h:J                  float64
# direct_rad:W                      float64
# direct_rad_1h:J                   float64
# effective_cloud_cover:p           float64
# elevation:m                       float64
# fresh_snow_12h:cm                 float64
# fresh_snow_1h:cm                  float64
# fresh_snow_24h:cm                 float64
# fresh_snow_3h:cm                  float64
# fresh_snow_6h:cm                  float64
# is_day:idx                        float64
# is_in_shadow:idx                  float64
# msl_pressure:hPa                  float64
# precip_5min:mm                    float64
# precip_type_5min:idx              float64
# pressure_100m:hPa                 float64
# pressure_50m:hPa                  float64
# prob_rime:p                       float64
# rain_water:kgm2                   float64
# relative_humidity_1000hPa:p       float64
# sfc_pressure:hPa                  float64
# snow_density:kgm3                 float64
# snow_depth:cm                     float64
# snow_drift:idx                    float64
# snow_melt_10min:mm                float64
# snow_water:kgm2                   float64
# sun_azimuth:d                     float64
# sun_elevation:d                   float64
# super_cooled_liquid_water:kgm2    float64
# t_1000hPa:K                       float64
# total_cloud_cover:p               float64
# visibility:m                      float64
# wind_speed_10m:ms                 float64
# wind_speed_u_10m:ms               float64
# wind_speed_v_10m:ms               float64
# wind_speed_w_1000hPa:ms           float64
# pv_measurement                    float64
# dtype: object

# %%
X['sun_azimuth:d'].plot()
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(X_est.isna(),cbar=False)
# Out:
# <AxesSubplot: ylabel='date_forecast'>

# %%
x = X_obs.T[X_obs.isna().mean()>0].T

# %%
x.isna().mean()*100
# Out:
# ceiling_height_agl:m    18.747103
# cloud_base_agl:m         6.797057
# snow_density:kgm3       97.704540
# dtype: float64

# %%
x.describe()
# Out:
#        ceiling_height_agl:m  cloud_base_agl:m  snow_density:kgm3
# count          96422.000000     110603.000000             2724.0
# mean            2907.949201       1737.142229              250.0
# std             2570.413231       1815.584087                0.0
# min               27.800000         27.900000              250.0
# 25%             1102.900000        590.700000              250.0
# 50%             1882.400000       1162.600000              250.0
# 75%             3969.750000       2079.600000              250.0
# max            12328.500000      11688.700000              250.0

# %%
x.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'ceiling_height_agl:m'}>,
#         <AxesSubplot: title={'center': 'cloud_base_agl:m'}>],
#        [<AxesSubplot: title={'center': 'snow_density:kgm3'}>,
#         <AxesSubplot: >]], dtype=object)

# %%
x_new = x.fillna(value={'snow_density:kgm3' : 0,
               'ceiling_height_agl:m' : x['ceiling_height_agl:m'].mean(),
                'cloud_base_agl:m' : x['cloud_base_agl:m'].mean()})

# %%
x_new.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'ceiling_height_agl:m'}>,
#         <AxesSubplot: title={'center': 'cloud_base_agl:m'}>],
#        [<AxesSubplot: title={'center': 'snow_density:kgm3'}>,
#         <AxesSubplot: >]], dtype=object)

# %%
sns.heatmap(X_obs.isna(),cbar=False)
# Out:
# <AxesSubplot: ylabel='date_forecast'>

# %%
fig, axes = plt.subplots(9, 5, figsize=(10, 10))

# Assuming X_obs is a DataFrame or Series
X_obs.plot(subplots=True, layout=(9, 5), ax=axes)

# Remove x-axis and y-axis labels from all subplots
for ax_row in axes:
    for ax in ax_row:
        ax.set_xlabel('')
        ax.set_ylabel('')

plt.savefig('test.png')
plt.show()
# Out:
# /var/folders/c6/6v_rvxyj6rj6m70q6t5cvn3w0000gn/T/ipykernel_2505/140188494.py:4: UserWarning: When passing multiple axes, layout keyword is ignored.
#   X_obs.plot(subplots=True, layout=(9, 5), ax=axes)

# %%
X.max()
# Out:
# absolute_humidity_2m:gm3               17.500
# air_density_2m:kgm3                     1.427
# ceiling_height_agl:m                12328.500
# clear_sky_energy_1h:J             3004692.800
# clear_sky_rad:W                       834.800
# cloud_base_agl:m                    11688.700
# dew_or_rime:idx                         1.000
# dew_point_2m:K                        293.800
# diffuse_rad:W                         336.700
# diffuse_rad_1h:J                  1182250.500
# direct_rad:W                          684.300
# direct_rad_1h:J                   2445832.500
# effective_cloud_cover:p               100.000
# elevation:m                             6.000
# fresh_snow_12h:cm                      15.000
# fresh_snow_1h:cm                        3.600
# fresh_snow_24h:cm                      15.000
# fresh_snow_3h:cm                        7.800
# fresh_snow_6h:cm                       14.600
# is_day:idx                              1.000
# is_in_shadow:idx                        1.000
# msl_pressure:hPa                     1044.000
# precip_5min:mm                          1.380
# precip_type_5min:idx                    6.000
# pressure_100m:hPa                    1030.900
# pressure_50m:hPa                     1037.300
# prob_rime:p                            83.400
# rain_water:kgm2                         1.400
# relative_humidity_1000hPa:p           100.000
# sfc_pressure:hPa                     1043.800
# snow_density:kgm3                     250.000
# snow_depth:cm                           6.300
# snow_drift:idx                          0.000
# snow_melt_10min:mm                      0.120
# snow_water:kgm2                         6.900
# sun_azimuth:d                         359.996
# sun_elevation:d                        49.880
# super_cooled_liquid_water:kgm2          1.400
# t_1000hPa:K                           303.300
# total_cloud_cover:p                   100.000
# visibility:m                        71349.900
# wind_speed_10m:ms                      15.200
# wind_speed_u_10m:ms                    12.200
# wind_speed_v_10m:ms                     8.600
# wind_speed_w_1000hPa:ms                 0.100
# pv_measurement                       5733.420
# dtype: float64

# %%
features = X_est.columns[1:]

for feature in features[:]:
    X_est[feature].plot()

# %%
plt.matshow(X_est.drop('date_calc', axis=1).corr())

# %%
sns.heatmap(X_est.drop('date_calc', axis=1).corr(), vmin=0, vmax=1)#, annot=True)
# Out:
# <AxesSubplot: >

# %%
X_est.drop('date_calc', axis=1).mean().sort_values().plot(style='.') # .sort_values()
# Out:
# <AxesSubplot: >

# %%
pd.plotting.scatter_matrix(X_est.drop('date_calc', axis=1).iloc[:,:5])#.corr()
# Out:
# array([[<AxesSubplot: xlabel='absolute_humidity_2m:gm3', ylabel='absolute_humidity_2m:gm3'>,
#         <AxesSubplot: xlabel='air_density_2m:kgm3', ylabel='absolute_humidity_2m:gm3'>,
#         <AxesSubplot: xlabel='ceiling_height_agl:m', ylabel='absolute_humidity_2m:gm3'>,
#         <AxesSubplot: xlabel='clear_sky_energy_1h:J', ylabel='absolute_humidity_2m:gm3'>,
#         <AxesSubplot: xlabel='clear_sky_rad:W', ylabel='absolute_humidity_2m:gm3'>],
#        [<AxesSubplot: xlabel='absolute_humidity_2m:gm3', ylabel='air_density_2m:kgm3'>,
#         <AxesSubplot: xlabel='air_density_2m:kgm3', ylabel='air_density_2m:kgm3'>,
#         <AxesSubplot: xlabel='ceiling_height_agl:m', ylabel='air_density_2m:kgm3'>,
#         <AxesSubplot: xlabel='clear_sky_energy_1h:J', ylabel='air_density_2m:kgm3'>,
#         <AxesSubplot: xlabel='clear_sky_rad:W', ylabel='air_density_2m:kgm3'>],
#        [<AxesSubplot: xlabel='absolute_humidity_2m:gm3', ylabel='ceiling_height_agl:m'>,
#         <AxesSubplot: xlabel='air_density_2m:kgm3', ylabel='ceiling_height_agl:m'>,
#         <AxesSubplot: xlabel='ceiling_height_agl:m', ylabel='ceiling_height_agl:m'>,
#         <AxesSubplot: xlabel='clear_sky_energy_1h:J', ylabel='ceiling_height_agl:m'>,
#         <AxesSubplot: xlabel='clear_sky_rad:W', ylabel='ceiling_height_agl:m'>],
#        [<AxesSubplot: xlabel='absolute_humidity_2m:gm3', ylabel='clear_sky_energy_1h:J'>,
#         <AxesSubplot: xlabel='air_density_2m:kgm3', ylabel='clear_sky_energy_1h:J'>,
#         <AxesSubplot: xlabel='ceiling_height_agl:m', ylabel='clear_sky_energy_1h:J'>,
#         <AxesSubplot: xlabel='clear_sky_energy_1h:J', ylabel='clear_sky_energy_1h:J'>,
#         <AxesSubplot: xlabel='clear_sky_rad:W', ylabel='clear_sky_energy_1h:J'>],
#        [<AxesSubplot: xlabel='absolute_humidity_2m:gm3', ylabel='clear_sky_rad:W'>,
#         <AxesSubplot: xlabel='air_density_2m:kgm3', ylabel='clear_sky_rad:W'>,
#         <AxesSubplot: xlabel='ceiling_height_agl:m', ylabel='clear_sky_rad:W'>,
#         <AxesSubplot: xlabel='clear_sky_energy_1h:J', ylabel='clear_sky_rad:W'>,
#         <AxesSubplot: xlabel='clear_sky_rad:W', ylabel='clear_sky_rad:W'>]],
#       dtype=object)

# %%
X.drop(['pv_measurement'], axis=1).corr()<
# Out:
#                                 absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# absolute_humidity_2m:gm3                        1.000000            -0.803326
# air_density_2m:kgm3                            -0.803326             1.000000
# ceiling_height_agl:m                            0.076754            -0.149976
# clear_sky_energy_1h:J                           0.352669            -0.474399
# clear_sky_rad:W                                 0.349790            -0.463730
# cloud_base_agl:m                                0.020805            -0.118813
# dew_or_rime:idx                                 0.122575            -0.058673
# dew_point_2m:K                                  0.974811            -0.838085
# diffuse_rad:W                                   0.285767            -0.403882
# diffuse_rad_1h:J                                0.291530            -0.416646
# direct_rad:W                                    0.240221            -0.396005
# direct_rad_1h:J                                 0.244153            -0.410888
# effective_cloud_cover:p                         0.021417            -0.066099
# elevation:m                                          NaN                  NaN
# fresh_snow_12h:cm                              -0.118776             0.062341
# fresh_snow_1h:cm                               -0.068740             0.043633
# fresh_snow_24h:cm                              -0.148366             0.074660
# fresh_snow_3h:cm                               -0.084930             0.052358
# fresh_snow_6h:cm                               -0.098726             0.058248
# is_day:idx                                      0.306243            -0.387462
# is_in_shadow:idx                               -0.318807             0.400142
# msl_pressure:hPa                                0.147742             0.280090
# precip_5min:mm                                  0.066528            -0.081588
# precip_type_5min:idx                           -0.020847            -0.013175
# pressure_100m:hPa                               0.165235             0.263772
# pressure_50m:hPa                                0.154298             0.275671
# prob_rime:p                                    -0.056014             0.072178
# rain_water:kgm2                                 0.259310            -0.161855
# relative_humidity_1000hPa:p                     0.160696             0.142590
# sfc_pressure:hPa                                0.143369             0.287497
# snow_density:kgm3                                    NaN                  NaN
# snow_depth:cm                                  -0.203651             0.316647
# snow_drift:idx                                       NaN                  NaN
# snow_melt_10min:mm                             -0.014042             0.014537
# snow_water:kgm2                                 0.033415            -0.063243
# sun_azimuth:d                                   0.023750            -0.064139
# sun_elevation:d                                 0.432066            -0.504546
# super_cooled_liquid_water:kgm2                  0.107140            -0.061943
# t_1000hPa:K                                     0.899403            -0.914845
# total_cloud_cover:p                             0.042977            -0.100941
# visibility:m                                   -0.157191            -0.011992
# wind_speed_10m:ms                              -0.156987            -0.017662
# wind_speed_u_10m:ms                             0.050194             0.025952
# wind_speed_v_10m:ms                            -0.256651             0.141692
# wind_speed_w_1000hPa:ms                         0.002927             0.003173
#
#                                 ceiling_height_agl:m  clear_sky_energy_1h:J  \
# absolute_humidity_2m:gm3                    0.076754               0.352669
# air_density_2m:kgm3                        -0.149976              -0.474399
# ceiling_height_agl:m                        1.000000               0.087360
# clear_sky_energy_1h:J                       0.087360               1.000000
# clear_sky_rad:W                             0.079520               0.992331
# cloud_base_agl:m                            0.706390               0.052849
# dew_or_rime:idx                             0.043554              -0.081113
# dew_point_2m:K                              0.066227               0.361910
# diffuse_rad:W                               0.097953               0.913991
# diffuse_rad_1h:J                            0.101989               0.923551
# direct_rad:W                                0.271475               0.722851
# direct_rad_1h:J                             0.281170               0.733839
# effective_cloud_cover:p                    -0.348479               0.003392
# elevation:m                                      NaN                    NaN
# fresh_snow_12h:cm                          -0.009282              -0.056937
# fresh_snow_1h:cm                           -0.003529              -0.037781
# fresh_snow_24h:cm                          -0.015660              -0.072858
# fresh_snow_3h:cm                           -0.006524              -0.046831
# fresh_snow_6h:cm                           -0.007522              -0.053043
# is_day:idx                                  0.051805               0.650362
# is_in_shadow:idx                           -0.057078              -0.692375
# msl_pressure:hPa                            0.070416               0.157719
# precip_5min:mm                              0.001550              -0.008976
# precip_type_5min:idx                       -0.046818              -0.029600
# pressure_100m:hPa                           0.074072               0.160352
# pressure_50m:hPa                            0.071997               0.154114
# prob_rime:p                                 0.001681              -0.050674
# rain_water:kgm2                            -0.151619               0.054826
# relative_humidity_1000hPa:p                -0.400662              -0.339987
# sfc_pressure:hPa                            0.069879               0.147875
# snow_density:kgm3                                NaN                    NaN
# snow_depth:cm                              -0.057617              -0.074666
# snow_drift:idx                                   NaN                    NaN
# snow_melt_10min:mm                         -0.030849              -0.020500
# snow_water:kgm2                            -0.170565              -0.037108
# sun_azimuth:d                               0.057474               0.038372
# sun_elevation:d                             0.079050               0.847857
# super_cooled_liquid_water:kgm2             -0.330302               0.016787
# t_1000hPa:K                                 0.232093               0.439300
# total_cloud_cover:p                         0.030325               0.010458
# visibility:m                                0.426252               0.091826
# wind_speed_10m:ms                          -0.160138               0.013464
# wind_speed_u_10m:ms                        -0.311788               0.069669
# wind_speed_v_10m:ms                         0.000645              -0.340359
# wind_speed_w_1000hPa:ms                    -0.000295              -0.005202
#
#                                 clear_sky_rad:W  cloud_base_agl:m  \
# absolute_humidity_2m:gm3               0.349790          0.020805
# air_density_2m:kgm3                   -0.463730         -0.118813
# ceiling_height_agl:m                   0.079520          0.706390
# clear_sky_energy_1h:J                  0.992331          0.052849
# clear_sky_rad:W                        1.000000          0.048901
# cloud_base_agl:m                       0.048901          1.000000
# dew_or_rime:idx                       -0.080447          0.037569
# dew_point_2m:K                         0.359033          0.011512
# diffuse_rad:W                          0.920057          0.036535
# diffuse_rad_1h:J                       0.915877          0.040458
# direct_rad:W                           0.730378          0.234547
# direct_rad_1h:J                        0.730008          0.241771
# effective_cloud_cover:p                0.003844         -0.329153
# elevation:m                                 NaN               NaN
# fresh_snow_12h:cm                     -0.055355         -0.006881
# fresh_snow_1h:cm                      -0.037536         -0.003691
# fresh_snow_24h:cm                     -0.072678         -0.007437
# fresh_snow_3h:cm                      -0.046207         -0.006798
# fresh_snow_6h:cm                      -0.052124         -0.008928
# is_day:idx                             0.650762          0.016528
# is_in_shadow:idx                      -0.696093         -0.019476
# msl_pressure:hPa                       0.158364          0.038796
# precip_5min:mm                        -0.009752         -0.022395
# precip_type_5min:idx                  -0.029515         -0.070958
# pressure_100m:hPa                      0.160682          0.042157
# pressure_50m:hPa                       0.154595          0.040453
# prob_rime:p                           -0.050452          0.021426
# rain_water:kgm2                        0.052756         -0.111394
# relative_humidity_1000hPa:p           -0.313426         -0.453720
# sfc_pressure:hPa                       0.148505          0.038711
# snow_density:kgm3                           NaN               NaN
# snow_depth:cm                         -0.074184         -0.057937
# snow_drift:idx                              NaN               NaN
# snow_melt_10min:mm                    -0.020468         -0.018717
# snow_water:kgm2                       -0.039407         -0.117254
# sun_azimuth:d                         -0.015973          0.046501
# sun_elevation:d                        0.851628          0.035930
# super_cooled_liquid_water:kgm2         0.017578         -0.262091
# t_1000hPa:K                            0.425132          0.198188
# total_cloud_cover:p                    0.010226         -0.071687
# visibility:m                           0.082866          0.453645
# wind_speed_10m:ms                      0.003589         -0.191220
# wind_speed_u_10m:ms                    0.064025         -0.392595
# wind_speed_v_10m:ms                   -0.325320          0.057235
# wind_speed_w_1000hPa:ms               -0.007277         -0.001230
#
#                                 dew_or_rime:idx  dew_point_2m:K  \
# absolute_humidity_2m:gm3               0.122575        0.974811
# air_density_2m:kgm3                   -0.058673       -0.838085
# ceiling_height_agl:m                   0.043554        0.066227
# clear_sky_energy_1h:J                 -0.081113        0.361910
# clear_sky_rad:W                       -0.080447        0.359033
# cloud_base_agl:m                       0.037569        0.011512
# dew_or_rime:idx                        1.000000        0.122914
# dew_point_2m:K                         0.122914        1.000000
# diffuse_rad:W                         -0.081409        0.297785
# diffuse_rad_1h:J                      -0.083184        0.303535
# direct_rad:W                          -0.056226        0.246408
# direct_rad_1h:J                       -0.057131        0.250556
# effective_cloud_cover:p               -0.050966        0.058611
# elevation:m                                 NaN             NaN
# fresh_snow_12h:cm                     -0.010774       -0.126135
# fresh_snow_1h:cm                      -0.010881       -0.075679
# fresh_snow_24h:cm                     -0.013471       -0.155511
# fresh_snow_3h:cm                      -0.010683       -0.092707
# fresh_snow_6h:cm                      -0.011769       -0.106614
# is_day:idx                            -0.103758        0.312253
# is_in_shadow:idx                       0.101198       -0.325433
# msl_pressure:hPa                       0.006677        0.137495
# precip_5min:mm                        -0.010952        0.065135
# precip_type_5min:idx                  -0.018203       -0.020947
# pressure_100m:hPa                      0.010445        0.155525
# pressure_50m:hPa                       0.009503        0.144142
# prob_rime:p                           -0.162775       -0.052135
# rain_water:kgm2                       -0.007454        0.237457
# relative_humidity_1000hPa:p            0.100930        0.161391
# sfc_pressure:hPa                       0.008596        0.132776
# snow_density:kgm3                           NaN             NaN
# snow_depth:cm                         -0.015377       -0.283572
# snow_drift:idx                              NaN             NaN
# snow_melt_10min:mm                    -0.003935       -0.009560
# snow_water:kgm2                       -0.022695        0.046037
# sun_azimuth:d                         -0.032112        0.024410
# sun_elevation:d                       -0.073038        0.442104
# super_cooled_liquid_water:kgm2        -0.036991        0.137996
# t_1000hPa:K                            0.108185        0.916093
# total_cloud_cover:p                   -0.033963        0.076805
# visibility:m                          -0.030082       -0.186035
# wind_speed_10m:ms                     -0.108904       -0.113240
# wind_speed_u_10m:ms                   -0.039055        0.091430
# wind_speed_v_10m:ms                    0.004990       -0.245691
# wind_speed_w_1000hPa:ms               -0.001832        0.004529
#
#                                 diffuse_rad:W  diffuse_rad_1h:J  direct_rad:W  \
# absolute_humidity_2m:gm3             0.285767          0.291530      0.240221
# air_density_2m:kgm3                 -0.403882         -0.416646     -0.396005
# ceiling_height_agl:m                 0.097953          0.101989      0.271475
# clear_sky_energy_1h:J                0.913991          0.923551      0.722851
# clear_sky_rad:W                      0.920057          0.915877      0.730378
# cloud_base_agl:m                     0.036535          0.040458      0.234547
# dew_or_rime:idx                     -0.081409         -0.083184     -0.056226
# dew_point_2m:K                       0.297785          0.303535      0.246408
# diffuse_rad:W                        1.000000          0.988827      0.562881
# diffuse_rad_1h:J                     0.988827          1.000000      0.562222
# direct_rad:W                         0.562881          0.562222      1.000000
# direct_rad_1h:J                      0.567564          0.571656      0.987502
# effective_cloud_cover:p              0.074776          0.070743     -0.334765
# elevation:m                               NaN               NaN           NaN
# fresh_snow_12h:cm                   -0.047200         -0.049682     -0.040320
# fresh_snow_1h:cm                    -0.037352         -0.037917     -0.027371
# fresh_snow_24h:cm                   -0.062497         -0.063264     -0.053498
# fresh_snow_3h:cm                    -0.045038         -0.046365     -0.033754
# fresh_snow_6h:cm                    -0.048510         -0.050379     -0.038206
# is_day:idx                           0.666929          0.667535      0.454321
# is_in_shadow:idx                    -0.709992         -0.704473     -0.487893
# msl_pressure:hPa                     0.139984          0.140664      0.182724
# precip_5min:mm                      -0.018540         -0.016786     -0.053864
# precip_type_5min:idx                -0.032447         -0.032196     -0.082865
# pressure_100m:hPa                    0.141504          0.142495      0.183297
# pressure_50m:hPa                     0.136221          0.137033      0.178049
# prob_rime:p                         -0.051497         -0.052241     -0.035249
# rain_water:kgm2                     -0.026948         -0.019427     -0.108947
# relative_humidity_1000hPa:p         -0.301662         -0.327222     -0.462414
# sfc_pressure:hPa                     0.130953          0.131590      0.172782
# snow_density:kgm3                         NaN               NaN           NaN
# snow_depth:cm                       -0.061064         -0.062391     -0.047552
# snow_drift:idx                            NaN               NaN           NaN
# snow_melt_10min:mm                  -0.020679         -0.020996     -0.014895
# snow_water:kgm2                     -0.084046         -0.076654     -0.149494
# sun_azimuth:d                       -0.014297          0.040736     -0.015985
# sun_elevation:d                      0.814543          0.814678      0.612368
# super_cooled_liquid_water:kgm2      -0.060067         -0.055316     -0.186228
# t_1000hPa:K                          0.355662          0.371006      0.389009
# total_cloud_cover:p                  0.093055          0.087602     -0.287523
# visibility:m                         0.109914          0.117408      0.324393
# wind_speed_10m:ms                   -0.004268          0.003476     -0.094749
# wind_speed_u_10m:ms                  0.059601          0.064171     -0.106731
# wind_speed_v_10m:ms                 -0.297577         -0.313361     -0.280098
# wind_speed_w_1000hPa:ms             -0.004315         -0.001775     -0.004122
#
#                                 direct_rad_1h:J  effective_cloud_cover:p  \
# absolute_humidity_2m:gm3               0.244153                 0.021417
# air_density_2m:kgm3                   -0.410888                -0.066099
# ceiling_height_agl:m                   0.281170                -0.348479
# clear_sky_energy_1h:J                  0.733839                 0.003392
# clear_sky_rad:W                        0.730008                 0.003844
# cloud_base_agl:m                       0.241771                -0.329153
# dew_or_rime:idx                       -0.057131                -0.050966
# dew_point_2m:K                         0.250556                 0.058611
# diffuse_rad:W                          0.567564                 0.074776
# diffuse_rad_1h:J                       0.571656                 0.070743
# direct_rad:W                           0.987502                -0.334765
# direct_rad_1h:J                        1.000000                -0.328086
# effective_cloud_cover:p               -0.328086                 1.000000
# elevation:m                                 NaN                      NaN
# fresh_snow_12h:cm                     -0.041804                 0.044524
# fresh_snow_1h:cm                      -0.027786                 0.030614
# fresh_snow_24h:cm                     -0.054237                 0.048323
# fresh_snow_3h:cm                      -0.034497                 0.038109
# fresh_snow_6h:cm                      -0.039252                 0.040707
# is_day:idx                             0.458943                -0.009809
# is_in_shadow:idx                      -0.490054                 0.010130
# msl_pressure:hPa                       0.182583                -0.217062
# precip_5min:mm                        -0.051910                 0.107544
# precip_type_5min:idx                  -0.082126                 0.169903
# pressure_100m:hPa                      0.183608                -0.217744
# pressure_50m:hPa                       0.178144                -0.217827
# prob_rime:p                           -0.035720                -0.091642
# rain_water:kgm2                       -0.107018                 0.230758
# relative_humidity_1000hPa:p           -0.498405                 0.333300
# sfc_pressure:hPa                       0.172661                -0.217880
# snow_density:kgm3                           NaN                      NaN
# snow_depth:cm                         -0.048556                -0.059415
# snow_drift:idx                              NaN                      NaN
# snow_melt_10min:mm                    -0.015092                 0.028139
# snow_water:kgm2                       -0.146149                 0.318374
# sun_azimuth:d                          0.022509                -0.019325
# sun_elevation:d                        0.614653                -0.019072
# super_cooled_liquid_water:kgm2        -0.183341                 0.441550
# t_1000hPa:K                            0.409116                -0.081035
# total_cloud_cover:p                   -0.278340                 0.930551
# visibility:m                           0.335001                -0.520736
# wind_speed_10m:ms                     -0.083970                 0.281547
# wind_speed_u_10m:ms                   -0.102378                 0.347713
# wind_speed_v_10m:ms                   -0.292968                 0.041496
# wind_speed_w_1000hPa:ms               -0.001234                -0.020832
#
#                                 elevation:m  fresh_snow_12h:cm  \
# absolute_humidity_2m:gm3                NaN          -0.118776
# air_density_2m:kgm3                     NaN           0.062341
# ceiling_height_agl:m                    NaN          -0.009282
# clear_sky_energy_1h:J                   NaN          -0.056937
# clear_sky_rad:W                         NaN          -0.055355
# cloud_base_agl:m                        NaN          -0.006881
# dew_or_rime:idx                         NaN          -0.010774
# dew_point_2m:K                          NaN          -0.126135
# diffuse_rad:W                           NaN          -0.047200
# diffuse_rad_1h:J                        NaN          -0.049682
# direct_rad:W                            NaN          -0.040320
# direct_rad_1h:J                         NaN          -0.041804
# effective_cloud_cover:p                 NaN           0.044524
# elevation:m                             NaN                NaN
# fresh_snow_12h:cm                       NaN           1.000000
# fresh_snow_1h:cm                        NaN           0.417867
# fresh_snow_24h:cm                       NaN           0.761019
# fresh_snow_3h:cm                        NaN           0.607662
# fresh_snow_6h:cm                        NaN           0.798863
# is_day:idx                              NaN          -0.046445
# is_in_shadow:idx                        NaN           0.048252
# msl_pressure:hPa                        NaN          -0.107728
# precip_5min:mm                          NaN           0.106552
# precip_type_5min:idx                    NaN           0.202828
# pressure_100m:hPa                       NaN          -0.109934
# pressure_50m:hPa                        NaN          -0.108741
# prob_rime:p                             NaN          -0.004370
# rain_water:kgm2                         NaN          -0.026561
# relative_humidity_1000hPa:p             NaN          -0.026868
# sfc_pressure:hPa                        NaN          -0.107531
# snow_density:kgm3                       NaN                NaN
# snow_depth:cm                           NaN           0.016247
# snow_drift:idx                          NaN                NaN
# snow_melt_10min:mm                      NaN          -0.003597
# snow_water:kgm2                         NaN           0.073198
# sun_azimuth:d                           NaN          -0.016367
# sun_elevation:d                         NaN          -0.070214
# super_cooled_liquid_water:kgm2          NaN          -0.015313
# t_1000hPa:K                             NaN          -0.110631
# total_cloud_cover:p                     NaN           0.045345
# visibility:m                            NaN           0.005115
# wind_speed_10m:ms                       NaN           0.057341
# wind_speed_u_10m:ms                     NaN          -0.025972
# wind_speed_v_10m:ms                     NaN           0.010816
# wind_speed_w_1000hPa:ms                 NaN          -0.001675
#
#                                 fresh_snow_1h:cm  fresh_snow_24h:cm  \
# absolute_humidity_2m:gm3               -0.068740          -0.148366
# air_density_2m:kgm3                     0.043633           0.074660
# ceiling_height_agl:m                   -0.003529          -0.015660
# clear_sky_energy_1h:J                  -0.037781          -0.072858
# clear_sky_rad:W                        -0.037536          -0.072678
# cloud_base_agl:m                       -0.003691          -0.007437
# dew_or_rime:idx                        -0.010881          -0.013471
# dew_point_2m:K                         -0.075679          -0.155511
# diffuse_rad:W                          -0.037352          -0.062497
# diffuse_rad_1h:J                       -0.037917          -0.063264
# direct_rad:W                           -0.027371          -0.053498
# direct_rad_1h:J                        -0.027786          -0.054237
# effective_cloud_cover:p                 0.030614           0.048323
# elevation:m                                  NaN                NaN
# fresh_snow_12h:cm                       0.417867           0.761019
# fresh_snow_1h:cm                        1.000000           0.286610
# fresh_snow_24h:cm                       0.286610           1.000000
# fresh_snow_3h:cm                        0.772051           0.417479
# fresh_snow_6h:cm                        0.592730           0.554686
# is_day:idx                             -0.043821          -0.060943
# is_in_shadow:idx                        0.044702           0.064057
# msl_pressure:hPa                       -0.051105          -0.142265
# precip_5min:mm                          0.093427           0.082152
# precip_type_5min:idx                    0.236528           0.163694
# pressure_100m:hPa                      -0.052360          -0.144925
# pressure_50m:hPa                       -0.051617          -0.143443
# prob_rime:p                            -0.002206           0.001157
# rain_water:kgm2                        -0.014471          -0.034413
# relative_humidity_1000hPa:p            -0.018993          -0.030325
# sfc_pressure:hPa                       -0.050861          -0.141940
# snow_density:kgm3                            NaN                NaN
# snow_depth:cm                           0.008198           0.012832
# snow_drift:idx                               NaN                NaN
# snow_melt_10min:mm                     -0.001919          -0.004726
# snow_water:kgm2                         0.010332           0.051767
# sun_azimuth:d                          -0.003200          -0.001167
# sun_elevation:d                        -0.049013          -0.089986
# super_cooled_liquid_water:kgm2         -0.021052          -0.015695
# t_1000hPa:K                            -0.066662          -0.135375
# total_cloud_cover:p                     0.033679           0.048005
# visibility:m                            0.010822           0.015150
# wind_speed_10m:ms                       0.025557           0.069235
# wind_speed_u_10m:ms                    -0.018895          -0.024371
# wind_speed_v_10m:ms                     0.000038           0.026106
# wind_speed_w_1000hPa:ms                -0.000894          -0.002201
#
#                                 fresh_snow_3h:cm  fresh_snow_6h:cm  \
# absolute_humidity_2m:gm3               -0.084930         -0.098726
# air_density_2m:kgm3                     0.052358          0.058248
# ceiling_height_agl:m                   -0.006524         -0.007522
# clear_sky_energy_1h:J                  -0.046831         -0.053043
# clear_sky_rad:W                        -0.046207         -0.052124
# cloud_base_agl:m                       -0.006798         -0.008928
# dew_or_rime:idx                        -0.010683         -0.011769
# dew_point_2m:K                         -0.092707         -0.106614
# diffuse_rad:W                          -0.045038         -0.048510
# diffuse_rad_1h:J                       -0.046365         -0.050379
# direct_rad:W                           -0.033754         -0.038206
# direct_rad_1h:J                        -0.034497         -0.039252
# effective_cloud_cover:p                 0.038109          0.040707
# elevation:m                                  NaN               NaN
# fresh_snow_12h:cm                       0.607662          0.798863
# fresh_snow_1h:cm                        0.772051          0.592730
# fresh_snow_24h:cm                       0.417479          0.554686
# fresh_snow_3h:cm                        1.000000          0.841975
# fresh_snow_6h:cm                        0.841975          1.000000
# is_day:idx                             -0.051634         -0.053646
# is_in_shadow:idx                        0.052336          0.054790
# msl_pressure:hPa                       -0.065929         -0.081201
# precip_5min:mm                          0.075712          0.071633
# precip_type_5min:idx                    0.207642          0.200310
# pressure_100m:hPa                      -0.067473         -0.083011
# pressure_50m:hPa                       -0.066566         -0.081964
# prob_rime:p                            -0.004446         -0.005705
# rain_water:kgm2                        -0.018242         -0.021284
# relative_humidity_1000hPa:p            -0.021272         -0.022285
# sfc_pressure:hPa                       -0.065654         -0.080909
# snow_density:kgm3                            NaN               NaN
# snow_depth:cm                           0.010480          0.012384
# snow_drift:idx                               NaN               NaN
# snow_melt_10min:mm                     -0.002419         -0.002873
# snow_water:kgm2                         0.025331          0.056887
# sun_azimuth:d                          -0.007660         -0.013388
# sun_elevation:d                        -0.060666         -0.067714
# super_cooled_liquid_water:kgm2         -0.024690         -0.026433
# t_1000hPa:K                            -0.082259         -0.094687
# total_cloud_cover:p                     0.039923          0.043297
# visibility:m                            0.008019          0.003834
# wind_speed_10m:ms                       0.035387          0.044813
# wind_speed_u_10m:ms                    -0.021080         -0.022855
# wind_speed_v_10m:ms                    -0.004293         -0.002945
# wind_speed_w_1000hPa:ms                -0.001126         -0.001338
#
#                                 is_day:idx  is_in_shadow:idx  \
# absolute_humidity_2m:gm3          0.306243         -0.318807
# air_density_2m:kgm3              -0.387462          0.400142
# ceiling_height_agl:m              0.051805         -0.057078
# clear_sky_energy_1h:J             0.650362         -0.692375
# clear_sky_rad:W                   0.650762         -0.696093
# cloud_base_agl:m                  0.016528         -0.019476
# dew_or_rime:idx                  -0.103758          0.101198
# dew_point_2m:K                    0.312253         -0.325433
# diffuse_rad:W                     0.666929         -0.709992
# diffuse_rad_1h:J                  0.667535         -0.704473
# direct_rad:W                      0.454321         -0.487893
# direct_rad_1h:J                   0.458943         -0.490054
# effective_cloud_cover:p          -0.009809          0.010130
# elevation:m                            NaN               NaN
# fresh_snow_12h:cm                -0.046445          0.048252
# fresh_snow_1h:cm                 -0.043821          0.044702
# fresh_snow_24h:cm                -0.060943          0.064057
# fresh_snow_3h:cm                 -0.051634          0.052336
# fresh_snow_6h:cm                 -0.053646          0.054790
# is_day:idx                        1.000000         -0.931190
# is_in_shadow:idx                 -0.931190          1.000000
# msl_pressure:hPa                  0.129921         -0.137785
# precip_5min:mm                   -0.019591          0.019103
# precip_type_5min:idx             -0.027687          0.028165
# pressure_100m:hPa                 0.130453         -0.138666
# pressure_50m:hPa                  0.125545         -0.133545
# prob_rime:p                      -0.072918          0.070415
# rain_water:kgm2                   0.047450         -0.048867
# relative_humidity_1000hPa:p      -0.209608          0.217308
# sfc_pressure:hPa                  0.120603         -0.128401
# snow_density:kgm3                      NaN               NaN
# snow_depth:cm                    -0.050156          0.054268
# snow_drift:idx                         NaN               NaN
# snow_melt_10min:mm               -0.010770          0.015227
# snow_water:kgm2                  -0.035189          0.037659
# sun_azimuth:d                    -0.021615          0.041000
# sun_elevation:d                   0.809292         -0.809546
# super_cooled_liquid_water:kgm2    0.015183         -0.014645
# t_1000hPa:K                       0.334500         -0.348383
# total_cloud_cover:p              -0.007607          0.006340
# visibility:m                      0.055117         -0.054293
# wind_speed_10m:ms                -0.002813          0.004532
# wind_speed_u_10m:ms               0.059911         -0.062077
# wind_speed_v_10m:ms              -0.264909          0.273668
# wind_speed_w_1000hPa:ms           0.005920         -0.002621
#
#                                 msl_pressure:hPa  precip_5min:mm  \
# absolute_humidity_2m:gm3                0.147742        0.066528
# air_density_2m:kgm3                     0.280090       -0.081588
# ceiling_height_agl:m                    0.070416        0.001550
# clear_sky_energy_1h:J                   0.157719       -0.008976
# clear_sky_rad:W                         0.158364       -0.009752
# cloud_base_agl:m                        0.038796       -0.022395
# dew_or_rime:idx                         0.006677       -0.010952
# dew_point_2m:K                          0.137495        0.065135
# diffuse_rad:W                           0.139984       -0.018540
# diffuse_rad_1h:J                        0.140664       -0.016786
# direct_rad:W                            0.182724       -0.053864
# direct_rad_1h:J                         0.182583       -0.051910
# effective_cloud_cover:p                -0.217062        0.107544
# elevation:m                                  NaN             NaN
# fresh_snow_12h:cm                      -0.107728        0.106552
# fresh_snow_1h:cm                       -0.051105        0.093427
# fresh_snow_24h:cm                      -0.142265        0.082152
# fresh_snow_3h:cm                       -0.065929        0.075712
# fresh_snow_6h:cm                       -0.081201        0.071633
# is_day:idx                              0.129921       -0.019591
# is_in_shadow:idx                       -0.137785        0.019103
# msl_pressure:hPa                        1.000000       -0.084508
# precip_5min:mm                         -0.084508        1.000000
# precip_type_5min:idx                   -0.113851        0.493385
# pressure_100m:hPa                       0.999770       -0.082877
# pressure_50m:hPa                        0.999913       -0.083678
# prob_rime:p                            -0.007590       -0.009084
# rain_water:kgm2                        -0.043171        0.178426
# relative_humidity_1000hPa:p            -0.098054        0.037856
# sfc_pressure:hPa                        0.999902       -0.084459
# snow_density:kgm3                            NaN             NaN
# snow_depth:cm                           0.079565       -0.019785
# snow_drift:idx                               NaN             NaN
# snow_melt_10min:mm                      0.001693       -0.005216
# snow_water:kgm2                        -0.175027        0.186284
# sun_azimuth:d                           0.001803       -0.008077
# sun_elevation:d                         0.194113       -0.019397
# super_cooled_liquid_water:kgm2         -0.033583        0.087218
# t_1000hPa:K                             0.051057        0.059324
# total_cloud_cover:p                    -0.208317        0.108827
# visibility:m                            0.055737       -0.086420
# wind_speed_10m:ms                      -0.210373        0.073496
# wind_speed_u_10m:ms                     0.082383        0.008148
# wind_speed_v_10m:ms                    -0.236951        0.023961
# wind_speed_w_1000hPa:ms                 0.022440       -0.002559
#
#                                 precip_type_5min:idx  pressure_100m:hPa  \
# absolute_humidity_2m:gm3                   -0.020847           0.165235
# air_density_2m:kgm3                        -0.013175           0.263772
# ceiling_height_agl:m                       -0.046818           0.074072
# clear_sky_energy_1h:J                      -0.029600           0.160352
# clear_sky_rad:W                            -0.029515           0.160682
# cloud_base_agl:m                           -0.070958           0.042157
# dew_or_rime:idx                            -0.018203           0.010445
# dew_point_2m:K                             -0.020947           0.155525
# diffuse_rad:W                              -0.032447           0.141504
# diffuse_rad_1h:J                           -0.032196           0.142495
# direct_rad:W                               -0.082865           0.183297
# direct_rad_1h:J                            -0.082126           0.183608
# effective_cloud_cover:p                     0.169903          -0.217744
# elevation:m                                      NaN                NaN
# fresh_snow_12h:cm                           0.202828          -0.109934
# fresh_snow_1h:cm                            0.236528          -0.052360
# fresh_snow_24h:cm                           0.163694          -0.144925
# fresh_snow_3h:cm                            0.207642          -0.067473
# fresh_snow_6h:cm                            0.200310          -0.083011
# is_day:idx                                 -0.027687           0.130453
# is_in_shadow:idx                            0.028165          -0.138666
# msl_pressure:hPa                           -0.113851           0.999770
# precip_5min:mm                              0.493385          -0.082877
# precip_type_5min:idx                        1.000000          -0.114500
# pressure_100m:hPa                          -0.114500           1.000000
# pressure_50m:hPa                           -0.114286           0.999918
# prob_rime:p                                -0.015279          -0.007539
# rain_water:kgm2                             0.121389          -0.039060
# relative_humidity_1000hPa:p                 0.059504          -0.098531
# sfc_pressure:hPa                           -0.114036           0.999688
# snow_density:kgm3                                NaN                NaN
# snow_depth:cm                              -0.021942           0.073476
# snow_drift:idx                                   NaN                NaN
# snow_melt_10min:mm                         -0.006454           0.001531
# snow_water:kgm2                             0.202259          -0.174601
# sun_azimuth:d                              -0.012651           0.003757
# sun_elevation:d                            -0.035064           0.197367
# super_cooled_liquid_water:kgm2              0.085165          -0.032528
# t_1000hPa:K                                -0.042715           0.069839
# total_cloud_cover:p                         0.150127          -0.207868
# visibility:m                               -0.165818           0.055440
# wind_speed_10m:ms                           0.128418          -0.213258
# wind_speed_u_10m:ms                         0.077588           0.080646
# wind_speed_v_10m:ms                         0.008356          -0.237673
# wind_speed_w_1000hPa:ms                    -0.003670           0.022606
#
#                                 pressure_50m:hPa  prob_rime:p  \
# absolute_humidity_2m:gm3                0.154298    -0.056014
# air_density_2m:kgm3                     0.275671     0.072178
# ceiling_height_agl:m                    0.071997     0.001681
# clear_sky_energy_1h:J                   0.154114    -0.050674
# clear_sky_rad:W                         0.154595    -0.050452
# cloud_base_agl:m                        0.040453     0.021426
# dew_or_rime:idx                         0.009503    -0.162775
# dew_point_2m:K                          0.144142    -0.052135
# diffuse_rad:W                           0.136221    -0.051497
# diffuse_rad_1h:J                        0.137033    -0.052241
# direct_rad:W                            0.178049    -0.035249
# direct_rad_1h:J                         0.178144    -0.035720
# effective_cloud_cover:p                -0.217827    -0.091642
# elevation:m                                  NaN          NaN
# fresh_snow_12h:cm                      -0.108741    -0.004370
# fresh_snow_1h:cm                       -0.051617    -0.002206
# fresh_snow_24h:cm                      -0.143443     0.001157
# fresh_snow_3h:cm                       -0.066566    -0.004446
# fresh_snow_6h:cm                       -0.081964    -0.005705
# is_day:idx                              0.125545    -0.072918
# is_in_shadow:idx                       -0.133545     0.070415
# msl_pressure:hPa                        0.999913    -0.007590
# precip_5min:mm                         -0.083678    -0.009084
# precip_type_5min:idx                   -0.114286    -0.015279
# pressure_100m:hPa                       0.999918    -0.007539
# pressure_50m:hPa                        1.000000    -0.006683
# prob_rime:p                            -0.006683     1.000000
# rain_water:kgm2                        -0.041042    -0.018505
# relative_humidity_1000hPa:p            -0.096420     0.028228
# sfc_pressure:hPa                        0.999918    -0.005794
# snow_density:kgm3                            NaN          NaN
# snow_depth:cm                           0.077404    -0.009589
# snow_drift:idx                               NaN          NaN
# snow_melt_10min:mm                      0.001706    -0.002453
# snow_water:kgm2                        -0.174830    -0.022203
# sun_azimuth:d                           0.002850    -0.026960
# sun_elevation:d                         0.190678    -0.074792
# super_cooled_liquid_water:kgm2         -0.033212    -0.037054
# t_1000hPa:K                             0.057750    -0.038695
# total_cloud_cover:p                    -0.208458    -0.088000
# visibility:m                            0.055106     0.009308
# wind_speed_10m:ms                      -0.212724    -0.067530
# wind_speed_u_10m:ms                     0.080750    -0.034482
# wind_speed_v_10m:ms                    -0.235305     0.011479
# wind_speed_w_1000hPa:ms                 0.022576    -0.001143
#
#                                 rain_water:kgm2  relative_humidity_1000hPa:p  \
# absolute_humidity_2m:gm3               0.259310                     0.160696
# air_density_2m:kgm3                   -0.161855                     0.142590
# ceiling_height_agl:m                  -0.151619                    -0.400662
# clear_sky_energy_1h:J                  0.054826                    -0.339987
# clear_sky_rad:W                        0.052756                    -0.313426
# cloud_base_agl:m                      -0.111394                    -0.453720
# dew_or_rime:idx                       -0.007454                     0.100930
# dew_point_2m:K                         0.237457                     0.161391
# diffuse_rad:W                         -0.026948                    -0.301662
# diffuse_rad_1h:J                      -0.019427                    -0.327222
# direct_rad:W                          -0.108947                    -0.462414
# direct_rad_1h:J                       -0.107018                    -0.498405
# effective_cloud_cover:p                0.230758                     0.333300
# elevation:m                                 NaN                          NaN
# fresh_snow_12h:cm                     -0.026561                    -0.026868
# fresh_snow_1h:cm                      -0.014471                    -0.018993
# fresh_snow_24h:cm                     -0.034413                    -0.030325
# fresh_snow_3h:cm                      -0.018242                    -0.021272
# fresh_snow_6h:cm                      -0.021284                    -0.022285
# is_day:idx                             0.047450                    -0.209608
# is_in_shadow:idx                      -0.048867                     0.217308
# msl_pressure:hPa                      -0.043171                    -0.098054
# precip_5min:mm                         0.178426                     0.037856
# precip_type_5min:idx                   0.121389                     0.059504
# pressure_100m:hPa                     -0.039060                    -0.098531
# pressure_50m:hPa                      -0.041042                    -0.096420
# prob_rime:p                           -0.018505                     0.028228
# rain_water:kgm2                        1.000000                     0.207574
# relative_humidity_1000hPa:p            0.207574                     1.000000
# sfc_pressure:hPa                      -0.043004                    -0.094276
# snow_density:kgm3                           NaN                          NaN
# snow_depth:cm                         -0.027606                     0.015223
# snow_drift:idx                              NaN                          NaN
# snow_melt_10min:mm                     0.019552                     0.014632
# snow_water:kgm2                        0.530343                     0.165579
# sun_azimuth:d                         -0.005391                    -0.155857
# sun_elevation:d                        0.068575                    -0.259691
# super_cooled_liquid_water:kgm2         0.349978                     0.278501
# t_1000hPa:K                            0.156184                    -0.199441
# total_cloud_cover:p                    0.184671                     0.246215
# visibility:m                          -0.391294                    -0.653141
# wind_speed_10m:ms                      0.066247                     0.010758
# wind_speed_u_10m:ms                    0.107560                     0.329268
# wind_speed_v_10m:ms                   -0.037166                    -0.074513
# wind_speed_w_1000hPa:ms               -0.003822                    -0.015978
#
#                                 sfc_pressure:hPa  snow_density:kgm3  \
# absolute_humidity_2m:gm3                0.143369                NaN
# air_density_2m:kgm3                     0.287497                NaN
# ceiling_height_agl:m                    0.069879                NaN
# clear_sky_energy_1h:J                   0.147875                NaN
# clear_sky_rad:W                         0.148505                NaN
# cloud_base_agl:m                        0.038711                NaN
# dew_or_rime:idx                         0.008596                NaN
# dew_point_2m:K                          0.132776                NaN
# diffuse_rad:W                           0.130953                NaN
# diffuse_rad_1h:J                        0.131590                NaN
# direct_rad:W                            0.172782                NaN
# direct_rad_1h:J                         0.172661                NaN
# effective_cloud_cover:p                -0.217880                NaN
# elevation:m                                  NaN                NaN
# fresh_snow_12h:cm                      -0.107531                NaN
# fresh_snow_1h:cm                       -0.050861                NaN
# fresh_snow_24h:cm                      -0.141940                NaN
# fresh_snow_3h:cm                       -0.065654                NaN
# fresh_snow_6h:cm                       -0.080909                NaN
# ...
# elevation:m                               NaN              NaN
# fresh_snow_12h:cm                   -0.016367        -0.070214
# fresh_snow_1h:cm                    -0.003200        -0.049013
# fresh_snow_24h:cm                   -0.001167        -0.089986
# fresh_snow_3h:cm                    -0.007660        -0.060666
# fresh_snow_6h:cm                    -0.013388        -0.067714
# is_day:idx                          -0.021615         0.809292
# is_in_shadow:idx                     0.041000        -0.809546
# msl_pressure:hPa                     0.001803         0.194113
# precip_5min:mm                      -0.008077        -0.019397
# precip_type_5min:idx                -0.012651        -0.035064
# pressure_100m:hPa                    0.003757         0.197367
# pressure_50m:hPa                     0.002850         0.190678
# prob_rime:p                         -0.026960        -0.074792
# rain_water:kgm2                     -0.005391         0.068575
# relative_humidity_1000hPa:p         -0.155857        -0.259691
# sfc_pressure:hPa                     0.001922         0.183970
# snow_density:kgm3                         NaN              NaN
# snow_depth:cm                       -0.004260        -0.083697
# snow_drift:idx                            NaN              NaN
# snow_melt_10min:mm                  -0.004440        -0.019459
# snow_water:kgm2                      0.004966        -0.048666
# sun_azimuth:d                        1.000000        -0.025110
# sun_elevation:d                     -0.025110         1.000000
# super_cooled_liquid_water:kgm2      -0.025614         0.020303
# t_1000hPa:K                          0.080914         0.478610
# total_cloud_cover:p                 -0.008524        -0.013890
# visibility:m                         0.072300         0.042883
# wind_speed_10m:ms                    0.046715        -0.024300
# wind_speed_u_10m:ms                  0.027749         0.076001
# wind_speed_v_10m:ms                 -0.068107        -0.339836
# wind_speed_w_1000hPa:ms              0.017278         0.000944
#
#                                 super_cooled_liquid_water:kgm2  t_1000hPa:K  \
# absolute_humidity_2m:gm3                              0.107140     0.899403
# air_density_2m:kgm3                                  -0.061943    -0.914845
# ceiling_height_agl:m                                 -0.330302     0.232093
# clear_sky_energy_1h:J                                 0.016787     0.439300
# clear_sky_rad:W                                       0.017578     0.425132
# cloud_base_agl:m                                     -0.262091     0.198188
# dew_or_rime:idx                                      -0.036991     0.108185
# dew_point_2m:K                                        0.137996     0.916093
# diffuse_rad:W                                        -0.060067     0.355662
# diffuse_rad_1h:J                                     -0.055316     0.371006
# direct_rad:W                                         -0.186228     0.389009
# direct_rad_1h:J                                      -0.183341     0.409116
# effective_cloud_cover:p                               0.441550    -0.081035
# elevation:m                                                NaN          NaN
# fresh_snow_12h:cm                                    -0.015313    -0.110631
# fresh_snow_1h:cm                                     -0.021052    -0.066662
# fresh_snow_24h:cm                                    -0.015695    -0.135375
# fresh_snow_3h:cm                                     -0.024690    -0.082259
# fresh_snow_6h:cm                                     -0.026433    -0.094687
# is_day:idx                                            0.015183     0.334500
# is_in_shadow:idx                                     -0.014645    -0.348383
# msl_pressure:hPa                                     -0.033583     0.051057
# precip_5min:mm                                        0.087218     0.059324
# precip_type_5min:idx                                  0.085165    -0.042715
# pressure_100m:hPa                                    -0.032528     0.069839
# pressure_50m:hPa                                     -0.033212     0.057750
# prob_rime:p                                          -0.037054    -0.038695
# rain_water:kgm2                                       0.349978     0.156184
# relative_humidity_1000hPa:p                           0.278501    -0.199441
# sfc_pressure:hPa                                     -0.033895     0.045687
# snow_density:kgm3                                          NaN          NaN
# snow_depth:cm                                        -0.043043    -0.265526
# snow_drift:idx                                             NaN          NaN
# snow_melt_10min:mm                                    0.040344    -0.012096
# snow_water:kgm2                                       0.330416    -0.010633
# sun_azimuth:d                                        -0.025614     0.080914
# sun_elevation:d                                       0.020303     0.478610
# super_cooled_liquid_water:kgm2                        1.000000     0.014960
# t_1000hPa:K                                           0.014960     1.000000
# total_cloud_cover:p                                   0.349380    -0.023281
# visibility:m                                         -0.500546     0.077042
# wind_speed_10m:ms                                     0.245656    -0.130812
# wind_speed_u_10m:ms                                   0.320735    -0.079874
# wind_speed_v_10m:ms                                   0.011027    -0.163935
# wind_speed_w_1000hPa:ms                              -0.008077     0.006053
#
#                                 total_cloud_cover:p  visibility:m  \
# absolute_humidity_2m:gm3                   0.042977     -0.157191
# air_density_2m:kgm3                       -0.100941     -0.011992
# ceiling_height_agl:m                       0.030325      0.426252
# clear_sky_energy_1h:J                      0.010458      0.091826
# clear_sky_rad:W                            0.010226      0.082866
# cloud_base_agl:m                          -0.071687      0.453645
# dew_or_rime:idx                           -0.033963     -0.030082
# dew_point_2m:K                             0.076805     -0.186035
# diffuse_rad:W                              0.093055      0.109914
# diffuse_rad_1h:J                           0.087602      0.117408
# direct_rad:W                              -0.287523      0.324393
# direct_rad_1h:J                           -0.278340      0.335001
# effective_cloud_cover:p                    0.930551     -0.520736
# elevation:m                                     NaN           NaN
# fresh_snow_12h:cm                          0.045345      0.005115
# fresh_snow_1h:cm                           0.033679      0.010822
# fresh_snow_24h:cm                          0.048005      0.015150
# fresh_snow_3h:cm                           0.039923      0.008019
# fresh_snow_6h:cm                           0.043297      0.003834
# is_day:idx                                -0.007607      0.055117
# is_in_shadow:idx                           0.006340     -0.054293
# msl_pressure:hPa                          -0.208317      0.055737
# precip_5min:mm                             0.108827     -0.086420
# precip_type_5min:idx                       0.150127     -0.165818
# pressure_100m:hPa                         -0.207868      0.055440
# pressure_50m:hPa                          -0.208458      0.055106
# prob_rime:p                               -0.088000      0.009308
# rain_water:kgm2                            0.184671     -0.391294
# relative_humidity_1000hPa:p                0.246215     -0.653141
# sfc_pressure:hPa                          -0.209021      0.054726
# snow_density:kgm3                               NaN           NaN
# snow_depth:cm                             -0.071724      0.031502
# snow_drift:idx                                  NaN           NaN
# snow_melt_10min:mm                         0.022909     -0.040714
# snow_water:kgm2                            0.258829     -0.412931
# sun_azimuth:d                             -0.008524      0.072300
# sun_elevation:d                           -0.013890      0.042883
# super_cooled_liquid_water:kgm2             0.349380     -0.500546
# t_1000hPa:K                               -0.023281      0.077042
# total_cloud_cover:p                        1.000000     -0.392913
# visibility:m                              -0.392913      1.000000
# wind_speed_10m:ms                          0.225615     -0.249834
# wind_speed_u_10m:ms                        0.247660     -0.509885
# wind_speed_v_10m:ms                        0.050126      0.056499
# wind_speed_w_1000hPa:ms                   -0.020298      0.001715
#
#                                 wind_speed_10m:ms  wind_speed_u_10m:ms  \
# absolute_humidity_2m:gm3                -0.156987             0.050194
# air_density_2m:kgm3                     -0.017662             0.025952
# ceiling_height_agl:m                    -0.160138            -0.311788
# clear_sky_energy_1h:J                    0.013464             0.069669
# clear_sky_rad:W                          0.003589             0.064025
# cloud_base_agl:m                        -0.191220            -0.392595
# dew_or_rime:idx                         -0.108904            -0.039055
# dew_point_2m:K                          -0.113240             0.091430
# diffuse_rad:W                           -0.004268             0.059601
# diffuse_rad_1h:J                         0.003476             0.064171
# direct_rad:W                            -0.094749            -0.106731
# direct_rad_1h:J                         -0.083970            -0.102378
# effective_cloud_cover:p                  0.281547             0.347713
# elevation:m                                   NaN                  NaN
# fresh_snow_12h:cm                        0.057341            -0.025972
# fresh_snow_1h:cm                         0.025557            -0.018895
# fresh_snow_24h:cm                        0.069235            -0.024371
# fresh_snow_3h:cm                         0.035387            -0.021080
# fresh_snow_6h:cm                         0.044813            -0.022855
# is_day:idx                              -0.002813             0.059911
# is_in_shadow:idx                         0.004532            -0.062077
# msl_pressure:hPa                        -0.210373             0.082383
# precip_5min:mm                           0.073496             0.008148
# precip_type_5min:idx                     0.128418             0.077588
# pressure_100m:hPa                       -0.213258             0.080646
# pressure_50m:hPa                        -0.212724             0.080750
# prob_rime:p                             -0.067530            -0.034482
# rain_water:kgm2                          0.066247             0.107560
# relative_humidity_1000hPa:p              0.010758             0.329268
# sfc_pressure:hPa                        -0.212136             0.080900
# snow_density:kgm3                             NaN                  NaN
# snow_depth:cm                           -0.036112            -0.030633
# snow_drift:idx                                NaN                  NaN
# snow_melt_10min:mm                       0.016822             0.018959
# snow_water:kgm2                          0.178017             0.097792
# sun_azimuth:d                            0.046715             0.027749
# sun_elevation:d                         -0.024300             0.076001
# super_cooled_liquid_water:kgm2           0.245656             0.320735
# t_1000hPa:K                             -0.130812            -0.079874
# total_cloud_cover:p                      0.225615             0.247660
# visibility:m                            -0.249834            -0.509885
# wind_speed_10m:ms                        1.000000             0.529668
# wind_speed_u_10m:ms                      0.529668             1.000000
# wind_speed_v_10m:ms                      0.065094            -0.080407
# wind_speed_w_1000hPa:ms                 -0.003675            -0.003673
#
#                                 wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms
# absolute_humidity_2m:gm3                  -0.256651                 0.002927
# air_density_2m:kgm3                        0.141692                 0.003173
# ceiling_height_agl:m                       0.000645                -0.000295
# clear_sky_energy_1h:J                     -0.340359                -0.005202
# clear_sky_rad:W                           -0.325320                -0.007277
# cloud_base_agl:m                           0.057235                -0.001230
# dew_or_rime:idx                            0.004990                -0.001832
# dew_point_2m:K                            -0.245691                 0.004529
# diffuse_rad:W                             -0.297577                -0.004315
# diffuse_rad_1h:J                          -0.313361                -0.001775
# direct_rad:W                              -0.280098                -0.004122
# direct_rad_1h:J                           -0.292968                -0.001234
# effective_cloud_cover:p                    0.041496                -0.020832
# elevation:m                                     NaN                      NaN
# fresh_snow_12h:cm                          0.010816                -0.001675
# fresh_snow_1h:cm                           0.000038                -0.000894
# fresh_snow_24h:cm                          0.026106                -0.002201
# fresh_snow_3h:cm                          -0.004293                -0.001126
# fresh_snow_6h:cm                          -0.002945                -0.001338
# is_day:idx                                -0.264909                 0.005920
# is_in_shadow:idx                           0.273668                -0.002621
# msl_pressure:hPa                          -0.236951                 0.022440
# precip_5min:mm                             0.023961                -0.002559
# precip_type_5min:idx                       0.008356                -0.003670
# pressure_100m:hPa                         -0.237673                 0.022606
# pressure_50m:hPa                          -0.235305                 0.022576
# prob_rime:p                                0.011479                -0.001143
# rain_water:kgm2                           -0.037166                -0.003822
# relative_humidity_1000hPa:p               -0.074513                -0.015978
# sfc_pressure:hPa                          -0.232819                 0.022525
# snow_density:kgm3                               NaN                      NaN
# snow_depth:cm                              0.059606                -0.001980
# snow_drift:idx                                  NaN                      NaN
# snow_melt_10min:mm                         0.025884                -0.000507
# snow_water:kgm2                            0.072358                -0.005446
# sun_azimuth:d                             -0.068107                 0.017278
# sun_elevation:d                           -0.339836                 0.000944
# super_cooled_liquid_water:kgm2             0.011027                -0.008077
# t_1000hPa:K                               -0.163935                 0.006053
# total_cloud_cover:p                        0.050126                -0.020298
# visibility:m                               0.056499                 0.001715
# wind_speed_10m:ms                          0.065094                -0.003675
# wind_speed_u_10m:ms                       -0.080407                -0.003673
# wind_speed_v_10m:ms                        1.000000                -0.021337
# wind_speed_w_1000hPa:ms                   -0.021337                 1.000000

# %%
X.pv_measurement.plot()
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(X.corr())
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(X.corr()[['pv_measurement']].sort_values(by='pv_measurement', ascending=False), vmin=0, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with pv_measurement', fontdict={'fontsize':18}, pad=16);

# %%
fig = plt.figure()
fig.set_size_inches(10, 4)
# Tracer le premier graphique dans la première colonne
ax = fig.add_subplot(1, 1, 1)
ax.plot(X_est['ceiling_height_agl:m'].loc['2022'], color='r',marker='+')
ax.plot(X_obs['ceiling_height_agl:m'].loc['2022'], color='b',marker='+')

# %%
.plot()
# Out:
# <AxesSubplot: xlabel='date_forecast'>

# %%
y.loc[:].plot()
# Out:
# <AxesSubplot: xlabel='time'>

# %%
#y.resample('Y').mean().plot()
y.resample('M').mean().plot()
# Out:
# <AxesSubplot: xlabel='time'>

# %%
plt.figure(figsize=(12, 8))
y.loc['2019'].plot()
y.loc['2019'].resample('M').mean().plot(label='moyenne par mois', lw=3, ls=':', alpha=0.8)
y.loc['2019'].resample('W').mean().plot(label='moyenne par semaine', lw=2, ls='--', alpha=0.8)
plt.legend()
plt.show()

# %%
y.resample('d').mean().plot()
# Out:
# <AxesSubplot: xlabel='time'>

# %%
pd.merge(X_est, X_obs)
# Out:
# Empty DataFrame
# Columns: [date_calc, absolute_humidity_2m:gm3, air_density_2m:kgm3, ceiling_height_agl:m, clear_sky_energy_1h:J, clear_sky_rad:W, cloud_base_agl:m, dew_or_rime:idx, dew_point_2m:K, diffuse_rad:W, diffuse_rad_1h:J, direct_rad:W, direct_rad_1h:J, effective_cloud_cover:p, elevation:m, fresh_snow_12h:cm, fresh_snow_1h:cm, fresh_snow_24h:cm, fresh_snow_3h:cm, fresh_snow_6h:cm, is_day:idx, is_in_shadow:idx, msl_pressure:hPa, precip_5min:mm, precip_type_5min:idx, pressure_100m:hPa, pressure_50m:hPa, prob_rime:p, rain_water:kgm2, relative_humidity_1000hPa:p, sfc_pressure:hPa, snow_density:kgm3, snow_depth:cm, snow_drift:idx, snow_melt_10min:mm, snow_water:kgm2, sun_azimuth:d, sun_elevation:d, super_cooled_liquid_water:kgm2, t_1000hPa:K, total_cloud_cover:p, visibility:m, wind_speed_10m:ms, wind_speed_u_10m:ms, wind_speed_v_10m:ms, wind_speed_w_1000hPa:ms]
# Index: []

# %%
X_est.index
# Out:
# DatetimeIndex(['2022-10-28 22:00:00', '2022-10-28 22:15:00',
#                '2022-10-28 22:30:00', '2022-10-28 22:45:00',
#                '2022-10-28 23:00:00', '2022-10-28 23:15:00',
#                '2022-10-28 23:30:00', '2022-10-28 23:45:00',
#                '2022-10-29 00:00:00', '2022-10-29 00:15:00',
#                ...
#                '2023-04-30 21:30:00', '2023-04-30 21:45:00',
#                '2023-04-30 22:00:00', '2023-04-30 22:15:00',
#                '2023-04-30 22:30:00', '2023-04-30 22:45:00',
#                '2023-04-30 23:00:00', '2023-04-30 23:15:00',
#                '2023-04-30 23:30:00', '2023-04-30 23:45:00'],
#               dtype='datetime64[ns]', name='date_forecast', length=17576, freq=None)
